# %%
import pandas as pd
import numpy as np
import random

import pandas as pd

with open("figure2.csv", 'r') as file:
    data = file.read().split('\n')[1:]

rows = [a.split(',') for a in data if a[0] == 'r']
heads = [data[i+1].split(',')[0] for i, a in enumerate(data) if a[0] == 'r'] 

for i in range(len(rows)):
    rows[i] = [b for b in rows[i] if b]
    rows[i].extend(rows[i].pop(-1).split(' '))
    rows[i] = [b for b in rows[i] if b]
    rows[i][0] = heads[i]
t_data = list(zip(*rows))

df = pd.DataFrame(t_data[1:], columns=t_data[0])
df[0:4]
# Out:
#   SLC24A4 KITLG 6P25.3 TYR-1 TYR-2 OCA2-1 OCA2-2 MC1R-1 MC1R-2
# 0    54.7  19.6   46.8  29.3  70.2   97.6   94.1   13.5    9.6
# 1    57.7  19.6   46.9  31.1  70.5     99   98.6   13.5    9.7
# 2    39.5  20.9   47.1  22.9  68.9   97.5   91.1     13   10.4
# 3      54  17.8   44.2  27.3  70.2   87.5     67   12.8    7.8

# %%
blue = [0]*2234
green = [1]*428
brown = [2]*324
data_dict = {}
data_dict['eye_color'] = blue + green + brown
col_count = [2234, 428, 324]

for pheno in df.columns:
    data_dict[pheno] = []
    for i, stat in enumerate(list(df[pheno][1:4])):
        amount = round(col_count[i]*(float(stat)/100))
        l = [1]*amount + [0]*(col_count[i]-amount)
        random.shuffle(l)
        data_dict[pheno].extend(l)
final_df = pd.DataFrame(data_dict)  
col_mv = final_df.pop("eye_color")
final_df.insert(9, "eye_color", col_mv)
eye_color = final_df['eye_color'].copy()
eye_color.loc[eye_color == 0] = "blue"
eye_color.loc[eye_color == 1] = "green"
eye_color.loc[eye_color == 2] = "brown"
eye_color
# Out:
# 0        blue
# 1        blue
# 2        blue
# 3        blue
# 4        blue
#         ...
# 2981    brown
# 2982    brown
# 2983    brown
# 2984    brown
# 2985    brown
# Name: eye_color, Length: 2986, dtype: object

# %%
class Node:
    def __init__(self, 
                 feature_index=None,
                 threshold=None,
                 left_node=None,
                 right_node=None,
                 info_gain=None,
                 id=None,
                 depth=None,
                 value=None,
                 types=None):
        self.feature_index = feature_index
        self.threshold = threshold
        self.right_node = right_node
        self.left_node = left_node
        self.info_gain = info_gain
        self.id = id
        self.depth = depth
        self.types = types
        # for leaf nnode
        self.value = value

# %%
class DecisionTree:
    def __init__(self, min_sample_split=30, max_depth=12):
        self.root = None

        #stopping conditions
        self.min_sample_split = min_sample_split
        self.max_depth = max_depth
    def build_tree(self, dataset, curr_depth=0, id=0):

        X, Y = dataset[:,:-1], dataset[:,-1]
        num_samples, num_features = np.shape(X)
        #print(num_samples, num_features)

        if num_samples >= self.min_sample_split and curr_depth <= self.max_depth:
            best_split = self.get_best_split(dataset, num_samples, num_features)
            #print(best_split["curr_gain"])
            #print(curr_depth)
            if best_split["curr_gain"] > 0:
            # left set
                left_subtree = self.build_tree(best_split["dataset_left"], curr_depth+1, id*2 + 1)
                #print(left_subtree)
                # right set
                right_subtree = self.build_tree(best_split["dataset_right"], curr_depth+1, id*2 + 2)
                

                return Node(best_split["feature_index"], best_split["threshold"], left_subtree, right_subtree, best_split["curr_gain"]
                            ,depth=curr_depth, id=id, types=Y)

        leaf_value = self.get_leaf_value(Y)
        #print(leaf_value)
        return Node(value=leaf_value, depth=curr_depth, id=id, types=Y)

    def get_best_split(self, dataset, num_samples, num_features):
        best_split = {"curr_gain": 0}
        max_infogain = -1000000000

        for feature_index in range(num_features):
            feature_values = dataset[:,feature_index]
            possible_thresholds = np.unique(feature_values)
            for threshold in possible_thresholds:
                dataset_left, dataset_right = self.split(dataset, feature_index, threshold) 
                if len(dataset_left) > 0 and len(dataset_right) > 0:
                    y, y_left, y_right = dataset[:, -1], dataset_left[:, -1], dataset_right[:, -1]
                    info_gain = self.information_gain(y, y_left, y_right, "gini")
                    #print(info_gain)
                    if info_gain > max_infogain:
                        #print('yay')
                        best_split["dataset_left"] = dataset_left
                        best_split["dataset_right"] = dataset_right
                        best_split["feature_index"] = feature_index
                        best_split["threshold"] = threshold
                        best_split["curr_gain"] = info_gain
                        max_infogain = info_gain
        #rint(max_infogain)
        return best_split

    def split(self, dataset, feature_index, threshold):
        dataset_left = np.array([sample for sample in dataset if sample[feature_index] <= threshold] )
        dataset_right = np.array([sample for sample in dataset if sample[feature_index] > threshold])
        return dataset_left, dataset_right        
    
    def information_gain(self, y, y_left, y_right, type):
        # weights might use later 
        weight_l = len(y_left)/len(y)
        weight_r = len(y_right)/len(y)
        if type == "gini":
            info_gain = self.gini_index(y) - (weight_l*self.gini_index(y_left) + weight_r*self.gini_index(y_right))
            #print(info_gain)
        # entropy maybe
        return info_gain

    def gini_index(self, y):
        class_labels = np.unique(y)
        gini = 0
        for cls in class_labels:
            p_cls = len(y[y==cls])/len(y)
            gini += p_cls**2
        #print(1- gini)
        return 1 - gini

    def get_leaf_value(self, y):
        values = list(y)
        return max(values, key=values.count)

    def fit(self, x, y):
        dataset = np.concatenate((x, y), axis=1)
        #print(dataset)
        self.root = self.build_tree(dataset)

    def print_tree(self, tree=None, depth=0, leaf_l=[], inner_l=[]):
        if not tree:
            tree = self.root
            print(self.root.feature_index)
        if tree.value is not None:
            leaf_l.append(tree)
            print("leaf: id="+str(tree.id) + " depth=" + str(tree.depth)+ " value="+ str(tree.value))
            
        else:
            inner_l.append(tree)
            print(" id=" + str(tree.id) + " depth=" + str(tree.depth) + " X_"+str(tree.feature_index), " thresh: "+str(tree.threshold), " info ", tree.info_gain)
            print(f"left:")
            leaf_l, inner_l = self.print_tree(tree.left_node, depth + 1, leaf_l, inner_l)
            print(f"right:")
            leaf_l, inner_l = self.print_tree(tree.right_node, depth + 1, leaf_l, inner_l)
        return leaf_l, inner_l
 
    # predict 1
    def make_prediction(self, x, tree):
        if tree.value != None:
            #print(tree.value)
            return tree.value
        feature_val = x[tree.feature_index]
        if feature_val <= tree.threshold:
            return self.make_prediction(x, tree.left_node)
        else:
            return self.make_prediction(x, tree.right_node)
            
    def predict(self, set, root=None):
        if not root:
            root = self.root
        predictions = [self.make_prediction(x, root) for x in set]
        return predictions
        # predict 1

    found = False
    def pruning(self, prunedList, tree=None):
        
        if self.found:
            return tree
        if tree == None:
            tree = self.root

        if tree.value != None:

            return tree
        
        if int(tree.id) == prunedList[0]:
            tree.value = self.get_leaf_value(tree.types)
            self.found = True
            return tree

        
        self.pruning(prunedList, tree=tree.left_node)

        if self.found:
            return tree
        

        self.pruning(prunedList, tree=tree.right_node)
        if self.found:
            return tree

        return tree

    
  
        
        

X = final_df.iloc[:, :-1].values
Y = final_df.iloc[:, -1].values.reshape(-1,1)

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2, random_state=41)

classifier = DecisionTree()
classifier.fit(X_train, Y_train)

#classifier.print_tree()

# %%
#classifier.print_tree()

Y_pred = list(classifier.predict(X_test))

from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test, Y_pred))

#print(len([1 for i, a in enumerate(Y_test) if a == 2 and Y_pred[i] == 2])/len([a for a in Y_test if a == 2]))
def score(Y_test, Y_pred, attributeList=[0,1,2]):
    scoreList = []
    for type in attributeList:
        scoreList.append(len([1 for i, a in enumerate(Y_test) if a == type and Y_pred[i] == type])/len([a for a in Y_test if a == type]))
    return scoreList

print(score(Y_test, Y_pred))
# Out:
# 0.7591973244147158
# [0.9888143176733781, 0.012048192771084338, 0.16176470588235295]

# %%
leaf, inner = classifier.print_tree()
# Out:
# 6
#  id=0 depth=0 X_6  thresh: 0  info  0.036636071279471605
# left:
#  id=1 depth=1 X_1  thresh: 0  info  0.01612625397853784
# left:
#  id=3 depth=2 X_4  thresh: 0  info  0.021379578963368173
# left:
#  id=7 depth=3 X_3  thresh: 0  info  0.0371180146266652
# left:
# leaf: id=15 depth=4 value=0
# right:
# leaf: id=16 depth=4 value=2
# right:
#  id=8 depth=3 X_5  thresh: 0  info  0.012655489453758995
# left:
# leaf: id=17 depth=4 value=2
# right:
#  id=18 depth=4 X_0  thresh: 0  info  0.010727452271230953
# left:
#  id=37 depth=5 X_2  thresh: 0  info  0.05370867334830315
# left:
# leaf: id=75 depth=6 value=1
# right:
# leaf: id=76 depth=6 value=2
# right:
#  id=38 depth=5 X_7  thresh: 0  info  0.010484761784039176
# left:
#  id=77 depth=6 X_3  thresh: 0  info  0.010126924115582026
# left:
#  id=155 depth=7 X_2  thresh: 0  info  0.00347222222222221
# left:
# leaf: id=311 depth=8 value=2
# right:
# leaf: id=312 depth=8 value=2
# right:
# leaf: id=156 depth=7 value=2
# right:
# leaf: id=78 depth=6 value=2
# right:
# leaf: id=4 depth=2 value=1
# right:
#  id=2 depth=1 X_5  thresh: 0  info  0.0069064547078791505
# left:
#  id=5 depth=2 X_2  thresh: 0  info  0.034281400966183484
# left:
# leaf: id=11 depth=3 value=2
# right:
# leaf: id=12 depth=3 value=0
# right:
#  id=6 depth=2 X_0  thresh: 0  info  0.003712605723440676
# left:
#  id=13 depth=3 X_3  thresh: 0  info  0.0010769193708194957
# left:
#  id=27 depth=4 X_8  thresh: 0  info  0.0004947192301724135
# left:
#  id=55 depth=5 X_1  thresh: 0  info  0.000379467845084136
# left:
#  id=111 depth=6 X_2  thresh: 0  info  7.773613438621929e-05
# left:
#  id=223 depth=7 X_4  thresh: 0  info  0.0012529136106656513
# left:
#  id=447 depth=8 X_7  thresh: 0  info  0.0056154402023366745
# left:
# leaf: id=895 depth=9 value=0
# right:
# leaf: id=896 depth=9 value=0
# right:
#  id=448 depth=8 X_7  thresh: 0  info  0.0012056107030500307
# left:
# leaf: id=897 depth=9 value=0
# right:
# leaf: id=898 depth=9 value=0
# right:
#  id=224 depth=7 X_7  thresh: 0  info  0.0011573715340100765
# left:
#  id=449 depth=8 X_4  thresh: 0  info  0.0004347097219487561
# left:
# leaf: id=899 depth=9 value=0
# right:
# leaf: id=900 depth=9 value=0
# right:
# leaf: id=450 depth=8 value=0
# right:
#  id=112 depth=6 X_4  thresh: 0  info  0.005559773163815951
# left:
# leaf: id=225 depth=7 value=0
# right:
#  id=226 depth=7 X_2  thresh: 0  info  0.0027662415622281
# left:
#  id=453 depth=8 X_7  thresh: 0  info  0.0007768744354111345
# left:
# leaf: id=907 depth=9 value=0
# right:
# leaf: id=908 depth=9 value=0
# right:
#  id=454 depth=8 X_7  thresh: 0  info  0.0012444864524260857
# left:
# leaf: id=909 depth=9 value=0
# right:
# leaf: id=910 depth=9 value=0
# right:
#  id=56 depth=5 X_4  thresh: 0  info  0.013663843012123311
# left:
# leaf: id=113 depth=6 value=0
# right:
#  id=114 depth=6 X_1  thresh: 0  info  0.006143697859406383
# left:
#  id=229 depth=7 X_7  thresh: 0  info  0.0027142169999313515
# left:
#  id=459 depth=8 X_2  thresh: 0  info  0.00238044783499336
# left:
# leaf: id=919 depth=9 value=0
# right:
# leaf: id=920 depth=9 value=0
# right:
# leaf: id=460 depth=8 value=0
# right:
# leaf: id=230 depth=7 value=0
# right:
#  id=28 depth=4 X_8  thresh: 0  info  0.0018979095719613426
# left:
#  id=57 depth=5 X_7  thresh: 0  info  0.0014868518445428358
# left:
#  id=115 depth=6 X_4  thresh: 0  info  0.0005227790482990047
# left:
#  id=231 depth=7 X_2  thresh: 0  info  0.0037179867949097
# left:
#  id=463 depth=8 X_1  thresh: 0  info  0.03885761755396083
# left:
# leaf: id=927 depth=9 value=0
# right:
# leaf: id=928 depth=9 value=1
# right:
# leaf: id=464 depth=8 value=0
# right:
#  id=232 depth=7 X_2  thresh: 0  info  0.0007722244085879848
# left:
#  id=465 depth=8 X_1  thresh: 0  info  0.001757369614512616
# left:
# leaf: id=931 depth=9 value=0
# right:
# leaf: id=932 depth=9 value=0
# right:
#  id=466 depth=8 X_1  thresh: 0  info  0.0019519215633365117
# left:
# leaf: id=933 depth=9 value=0
# right:
# leaf: id=934 depth=9 value=0
# right:
#  id=116 depth=6 X_1  thresh: 0  info  0.006493236212278847
# left:
# leaf: id=233 depth=7 value=0
# right:
# leaf: id=234 depth=7 value=0
# right:
# leaf: id=58 depth=5 value=0
# right:
#  id=14 depth=3 X_3  thresh: 0  info  0.0015510996753489437
# left:
#  id=29 depth=4 X_8  thresh: 0  info  0.0006833619012007741
# left:
#  id=59 depth=5 X_7  thresh: 0  info  0.0004259355736203063
# left:
#  id=119 depth=6 X_1  thresh: 0  info  0.0002523125481491695
# left:
#  id=239 depth=7 X_4  thresh: 0  info  0.00019756866612014035
# left:
#  id=479 depth=8 X_2  thresh: 0  info  0.00099877957469241
# left:
# leaf: id=959 depth=9 value=0
# right:
# leaf: id=960 depth=9 value=0
# right:
#  id=480 depth=8 X_2  thresh: 0  info  4.920590000867531e-05
# left:
# leaf: id=961 depth=9 value=0
# right:
# leaf: id=962 depth=9 value=0
# right:
#  id=240 depth=7 X_2  thresh: 0  info  0.007754291102216759
# left:
#  id=481 depth=8 X_4  thresh: 0  info  0.004083376940519801
# left:
# leaf: id=963 depth=9 value=0
# right:
# leaf: id=964 depth=9 value=0
# right:
#  id=482 depth=8 X_4  thresh: 0  info  0.0007134363852554504
# left:
# leaf: id=965 depth=9 value=0
# right:
# leaf: id=966 depth=9 value=0
# right:
#  id=120 depth=6 X_4  thresh: 0  info  0.0050466043310408715
# left:
#  id=241 depth=7 X_2  thresh: 0  info  0.004708427448859576
# left:
# leaf: id=483 depth=8 value=0
# right:
# leaf: id=484 depth=8 value=0
# right:
#  id=242 depth=7 X_2  thresh: 0  info  0.0024185191659492067
# left:
#  id=485 depth=8 X_1  thresh: 0  info  0.0053058180185721615
# left:
# leaf: id=971 depth=9 value=0
# right:
# leaf: id=972 depth=9 value=0
# right:
#  id=486 depth=8 X_1  thresh: 0  info  0.008639459946309491
# left:
# leaf: id=973 depth=9 value=0
# right:
# leaf: id=974 depth=9 value=0
# right:
#  id=60 depth=5 X_1  thresh: 0  info  0.0094736842105263
# left:
#  id=121 depth=6 X_2  thresh: 0  info  0.0035587873191751385
# left:
#  id=243 depth=7 X_4  thresh: 0  info  0.002225783475783505
# left:
# leaf: id=487 depth=8 value=0
# right:
# leaf: id=488 depth=8 value=0
# right:
#  id=244 depth=7 X_4  thresh: 0  info  0.010351377018043673
# left:
# leaf: id=489 depth=8 value=0
# right:
# leaf: id=490 depth=8 value=0
# right:
# leaf: id=122 depth=6 value=0
# right:
#  id=30 depth=4 X_4  thresh: 0  info  0.000979799614059862
# left:
#  id=61 depth=5 X_1  thresh: 0  info  0.0035348433002009294
# left:
#  id=123 depth=6 X_8  thresh: 0  info  0.0024928774928777014
# left:
#  id=247 depth=7 X_2  thresh: 0  info  0.0006650615341276811
# left:
#  id=495 depth=8 X_7  thresh: 0  info  0.001498439125910675
# left:
# leaf: id=991 depth=9 value=0
# right:
# leaf: id=992 depth=9 value=0
# right:
#  id=496 depth=8 X_7  thresh: 0  info  9.392905225613646e-05
# left:
# leaf: id=993 depth=9 value=0
# right:
# leaf: id=994 depth=9 value=0
# right:
# leaf: id=248 depth=7 value=0
# right:
# leaf: id=124 depth=6 value=0
# right:
#  id=62 depth=5 X_7  thresh: 0  info  0.0011575597981126617
# left:
#  id=125 depth=6 X_1  thresh: 0  info  0.003063372123925018
# left:
#  id=251 depth=7 X_8  thresh: 0  info  0.0018387050470543564
# left:
#  id=503 depth=8 X_2  thresh: 0  info  0.00017579225185443415
# left:
# leaf: id=1007 depth=9 value=0
# right:
# leaf: id=1008 depth=9 value=0
# right:
# leaf: id=504 depth=8 value=0
# right:
#  id=252 depth=7 X_2  thresh: 0  info  0.00047413793103467244
# left:
# leaf: id=505 depth=8 value=0
# right:
# leaf: id=506 depth=8 value=0
# right:
#  id=126 depth=6 X_1  thresh: 0  info  0.009306122448979326
# left:
# leaf: id=253 depth=7 value=0
# right:
# leaf: id=254 depth=7 value=0

# %%
print([a.id for a in leaf])
l = [a.id for a in leaf]
print([a.id for a in inner])
# Out:
# [15, 16, 17, 75, 76, 311, 312, 156, 78, 4, 11, 12, 895, 896, 897, 898, 899, 900, 450, 225, 907, 908, 909, 910, 113, 919, 920, 460, 230, 927, 928, 464, 931, 932, 933, 934, 233, 234, 58, 959, 960, 961, 962, 963, 964, 965, 966, 483, 484, 971, 972, 973, 974, 487, 488, 489, 490, 122, 991, 992, 993, 994, 248, 124, 1007, 1008, 504, 505, 506, 253, 254]
# [0, 1, 3, 7, 8, 18, 37, 38, 77, 155, 2, 5, 6, 13, 27, 55, 111, 223, 447, 448, 224, 449, 112, 226, 453, 454, 56, 114, 229, 459, 28, 57, 115, 231, 463, 232, 465, 466, 116, 14, 29, 59, 119, 239, 479, 480, 240, 481, 482, 120, 241, 242, 485, 486, 60, 121, 243, 244, 30, 61, 123, 247, 495, 496, 62, 125, 251, 503, 252, 126]

# %% [markdown]
# pruning

# %%
def pruneClass(classifier):
    import copy
    max_accuracy = score(Y_test, Y_pred, [2])
    for node in inner:
        print(node.id, end=", ")
        temp = copy.deepcopy(classifier)
        temp.pruning([node.id])
        temp_preds = list(temp.predict(X_test))
        accuracy = score(Y_test, temp_preds, [2])
        if accuracy > max_accuracy:
            best_one = temp
            max_accuracy = accuracy
            print(max_accuracy, node.id)
    return best_one

# %%
best_one = pruneClass(classifier)
newbest = pruneClass(best_one)
best_one
# Out:
# 0, 1, [0.3382352941176471] 1
# 3, 7, 8, 18, 37, 38, 77, 155, 2, 5, 6, 13, 27, 55, 111, 223, 447, 448, 224, 449, 112, 226, 453, 454, 56, 114, 229, 459, 28, 57, 115, 231, 463, 232, 465, 466, 116, 14, 29, 59, 119, 239, 479, 480, 240, 481, 482, 120, 241, 242, 485, 486, 60, 121, 243, 244, 30, 61, 123, 247, 495, 496, 62, 125, 251, 503, 252, 126, 0, [0.3382352941176471] 0
# 1, 3, 7, 8, 18, 37, 38, 77, 155, 2, 5, 6, 13, 27, 55, 111, 223, 447, 448, 224, 449, 112, 226, 453, 454, 56, 114, 229, 459, 28, 57, 115, 231, 463, 232, 465, 466, 116, 14, 29, 59, 119, 239, 479, 480, 240, 481, 482, 120, 241, 242, 485, 486, 60, 121, 243, 244, 30, 61, 123, 247, 495, 496, 62, 125, 251, 503, 252, 126,
