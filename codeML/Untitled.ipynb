# %%
import pandas as pd
import numpy as np
import random

import pandas as pd

with open("figure2.csv", 'r') as file:
    data = file.read().split('\n')[1:]

rows = [a.split(',') for a in data if a[0] == 'r']
heads = [data[i+1].split(',')[0] for i, a in enumerate(data) if a[0] == 'r'] 

for i in range(len(rows)):
    rows[i] = [b for b in rows[i] if b]
    rows[i].extend(rows[i].pop(-1).split(' '))
    rows[i] = [b for b in rows[i] if b]
    rows[i][0] = heads[i]
t_data = list(zip(*rows))

df = pd.DataFrame(t_data[1:], columns=t_data[0])
df[0:4]
# Out:
#   SLC24A4 KITLG 6P25.3 TYR-1 TYR-2 OCA2-1 OCA2-2 MC1R-1 MC1R-2
# 0    54.7  19.6   46.8  29.3  70.2   97.6   94.1   13.5    9.6
# 1    57.7  19.6   46.9  31.1  70.5     99   98.6   13.5    9.7
# 2    39.5  20.9   47.1  22.9  68.9   97.5   91.1     13   10.4
# 3      54  17.8   44.2  27.3  70.2   87.5     67   12.8    7.8

# %%
blue = [0]*2234
green = [1]*428
brown = [2]*324
data_dict = {}
data_dict['eye_color'] = blue + green + brown
col_count = [2234, 428, 324]

for pheno in df.columns:
    data_dict[pheno] = []
    for i, stat in enumerate(list(df[pheno][1:4])):
        amount = round(col_count[i]*(float(stat)/100))
        l = [1]*amount + [0]*(col_count[i]-amount)
        random.shuffle(l)
        data_dict[pheno].extend(l)
final_df = pd.DataFrame(data_dict)  
col_mv = final_df.pop("eye_color")
final_df.insert(9, "eye_color", col_mv)
eye_color = final_df['eye_color'].copy()
eye_color.loc[eye_color == 0] = "blue"
eye_color.loc[eye_color == 1] = "green"
eye_color.loc[eye_color == 2] = "brown"
eye_color
# Out:
# 0        blue
# 1        blue
# 2        blue
# 3        blue
# 4        blue
#         ...
# 2981    brown
# 2982    brown
# 2983    brown
# 2984    brown
# 2985    brown
# Name: eye_color, Length: 2986, dtype: object

# %%
class Node:
    def __init__(self, 
                 feature_index=None,
                 threshold=None,
                 left_node=None,
                 right_node=None,
                 info_gain=None,
                 id=None,
                 depth=None,
                 value=None,
                 types=None):
        self.feature_index = feature_index
        self.threshold = threshold
        self.right_node = right_node
        self.left_node = left_node
        self.info_gain = info_gain
        self.id = id
        self.depth = depth
        self.types = types
        # for leaf nnode
        self.value = value

# %%
class DecisionTree:
    def __init__(self, min_sample_split=30, max_depth=12):
        self.root = None

        #stopping conditions
        self.min_sample_split = min_sample_split
        self.max_depth = max_depth
    def build_tree(self, dataset, curr_depth=0, id=0):

        X, Y = dataset[:,:-1], dataset[:,-1]
        num_samples, num_features = np.shape(X)
        #print(num_samples, num_features)

        if num_samples >= self.min_sample_split and curr_depth <= self.max_depth:
            best_split = self.get_best_split(dataset, num_samples, num_features)
            #print(best_split["curr_gain"])
            #print(curr_depth)
            if best_split["curr_gain"] > 0:
            # left set
                left_subtree = self.build_tree(best_split["dataset_left"], curr_depth+1, id*2 + 1)
                #print(left_subtree)
                # right set
                right_subtree = self.build_tree(best_split["dataset_right"], curr_depth+1, id*2 + 2)
                

                return Node(best_split["feature_index"], best_split["threshold"], left_subtree, right_subtree, best_split["curr_gain"]
                            ,depth=curr_depth, id=id, types=Y)

        leaf_value = self.get_leaf_value(Y)
        #print(leaf_value)
        return Node(value=leaf_value, depth=curr_depth, id=id, types=Y)

    def get_best_split(self, dataset, num_samples, num_features):
        best_split = {"curr_gain": 0}
        max_infogain = -1000000000

        for feature_index in range(num_features):
            feature_values = dataset[:,feature_index]
            possible_thresholds = np.unique(feature_values)
            for threshold in possible_thresholds:
                dataset_left, dataset_right = self.split(dataset, feature_index, threshold) 
                if len(dataset_left) > 0 and len(dataset_right) > 0:
                    y, y_left, y_right = dataset[:, -1], dataset_left[:, -1], dataset_right[:, -1]
                    info_gain = self.information_gain(y, y_left, y_right, "gini")
                    #print(info_gain)
                    if info_gain > max_infogain:
                        #print('yay')
                        best_split["dataset_left"] = dataset_left
                        best_split["dataset_right"] = dataset_right
                        best_split["feature_index"] = feature_index
                        best_split["threshold"] = threshold
                        best_split["curr_gain"] = info_gain
                        max_infogain = info_gain
        #rint(max_infogain)
        return best_split

    def split(self, dataset, feature_index, threshold):
        dataset_left = np.array([sample for sample in dataset if sample[feature_index] <= threshold] )
        dataset_right = np.array([sample for sample in dataset if sample[feature_index] > threshold])
        return dataset_left, dataset_right        
    
    def information_gain(self, y, y_left, y_right, type):
        # weights might use later 
        weight_l = len(y_left)/len(y)
        weight_r = len(y_right)/len(y)
        if type == "gini":
            info_gain = self.gini_index(y) - (weight_l*self.gini_index(y_left) + weight_r*self.gini_index(y_right))
            #print(info_gain)
        # entropy maybe
        return info_gain

    def gini_index(self, y):
        class_labels = np.unique(y)
        gini = 0
        for cls in class_labels:
            p_cls = len(y[y==cls])/len(y)
            gini += p_cls**2
        #print(1- gini)
        return 1 - gini

    def get_leaf_value(self, y):
        values = list(y)
        return max(values, key=values.count)

    def fit(self, x, y):
        dataset = np.concatenate((x, y), axis=1)
        #print(dataset)
        self.root = self.build_tree(dataset)

    def print_tree(self, tree=None, depth=0, leaf_l=[], inner_l=[]):
        if not tree:
            tree = self.root
            print(self.root.feature_index)
        if tree.value is not None:
            leaf_l.append(tree)
            print("leaf: id="+str(tree.id) + " depth=" + str(tree.depth)+ " value="+ str(tree.value))
            
        else:
            inner_l.append(tree)
            print(" id=" + str(tree.id) + " depth=" + str(tree.depth) + " X_"+str(tree.feature_index), " thresh: "+str(tree.threshold), " info ", tree.info_gain)
            print(f"left:")
            leaf_l, inner_l = self.print_tree(tree.left_node, depth + 1, leaf_l, inner_l)
            print(f"right:")
            leaf_l, inner_l = self.print_tree(tree.right_node, depth + 1, leaf_l, inner_l)
        return leaf_l, inner_l
 
    # predict 1
    def make_prediction(self, x, tree):
        if tree.value != None:
            #print(tree.value)
            return tree.value
        feature_val = x[tree.feature_index]
        if feature_val <= tree.threshold:
            return self.make_prediction(x, tree.left_node)
        else:
            return self.make_prediction(x, tree.right_node)
            
    def predict(self, set, root=None):
        if not root:
            root = self.root
        predictions = [self.make_prediction(x, root) for x in set]
        return predictions
        # predict 1

    found = False
    def pruning(self, prunedList, tree=None):
        
        if self.found:
            return tree
        if tree == None:
            tree = self.root

        if tree.value != None:

            return tree
        
        if int(tree.id) == prunedList[0]:
            tree.value = self.get_leaf_value(tree.types)
            self.found = True
            return tree

        
        self.pruning(prunedList, tree=tree.left_node)

        if self.found:
            return tree
        

        self.pruning(prunedList, tree=tree.right_node)
        if self.found:
            return tree

        return tree

    
  
        
        

X = final_df.iloc[:, :-1].values
Y = final_df.iloc[:, -1].values.reshape(-1,1)

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2, random_state=41)

classifier = DecisionTree()
classifier.fit(X_train, Y_train)

#classifier.print_tree()

# %%
#classifier.print_tree()

Y_pred = list(classifier.predict(X_test))

from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test, Y_pred))

#print(len([1 for i, a in enumerate(Y_test) if a == 2 and Y_pred[i] == 2])/len([a for a in Y_test if a == 2]))
def score(Y_test, Y_pred, attributeList=[0,1,2]):
    scoreList = []
    for type in attributeList:
        scoreList.append(len([1 for i, a in enumerate(Y_test) if a == type and Y_pred[i] == type])/len([a for a in Y_test if a == type]))
    return scoreList

print(score(Y_test, Y_pred))
# Out:
# 0.7859531772575251
# [0.9865771812080537, 0.0, 0.4264705882352941]

# %%
leaf, inner = classifier.print_tree()
# Out:
# 6
#  id=0 depth=0 X_6  thresh: 0  info  0.03433817637790765
# left:
#  id=1 depth=1 X_5  thresh: 0  info  0.020354400662355165
# left:
# leaf: id=3 depth=2 value=2
# right:
#  id=4 depth=2 X_3  thresh: 0  info  0.006317976556072025
# left:
#  id=9 depth=3 X_7  thresh: 0  info  0.010664122752742755
# left:
#  id=19 depth=4 X_4  thresh: 0  info  0.006785619131784215
# left:
# leaf: id=39 depth=5 value=2
# right:
#  id=40 depth=5 X_1  thresh: 0  info  0.008922021870042207
# left:
#  id=81 depth=6 X_2  thresh: 0  info  0.0038628354567634693
# left:
#  id=163 depth=7 X_8  thresh: 0  info  0.00529844290657433
# left:
#  id=327 depth=8 X_0  thresh: 0  info  0.013671875
# left:
# leaf: id=655 depth=9 value=2
# right:
# leaf: id=656 depth=9 value=2
# right:
# leaf: id=328 depth=8 value=2
# right:
# leaf: id=164 depth=7 value=2
# right:
# leaf: id=82 depth=6 value=2
# right:
# leaf: id=20 depth=4 value=2
# right:
# leaf: id=10 depth=3 value=2
# right:
#  id=2 depth=1 X_5  thresh: 0  info  0.005389197616847974
# left:
#  id=5 depth=2 X_3  thresh: 0  info  0.056638596491228044
# left:
#  id=11 depth=3 X_4  thresh: 0  info  0.0906847077207188
# left:
# leaf: id=23 depth=4 value=2
# right:
# leaf: id=24 depth=4 value=0
# right:
# leaf: id=12 depth=3 value=2
# right:
#  id=6 depth=2 X_0  thresh: 0  info  0.0044509744664642525
# left:
#  id=13 depth=3 X_3  thresh: 0  info  0.0006804978330644529
# left:
#  id=27 depth=4 X_7  thresh: 0  info  0.0005479725091973586
# left:
#  id=55 depth=5 X_4  thresh: 0  info  0.00019827506487501978
# left:
#  id=111 depth=6 X_8  thresh: 0  info  0.006847941352759512
# left:
#  id=223 depth=7 X_2  thresh: 0  info  0.005450652988418514
# left:
#  id=447 depth=8 X_1  thresh: 0  info  0.009362880886426561
# left:
# leaf: id=895 depth=9 value=0
# right:
# leaf: id=896 depth=9 value=0
# right:
#  id=448 depth=8 X_1  thresh: 0  info  0.0017987143972449382
# left:
# leaf: id=897 depth=9 value=0
# right:
# leaf: id=898 depth=9 value=0
# right:
# leaf: id=224 depth=7 value=0
# right:
#  id=112 depth=6 X_8  thresh: 0  info  0.0016567565711275711
# left:
#  id=225 depth=7 X_1  thresh: 0  info  0.00043927961425460627
# left:
#  id=451 depth=8 X_2  thresh: 0  info  0.001501777066160559
# left:
# leaf: id=903 depth=9 value=0
# right:
# leaf: id=904 depth=9 value=0
# right:
#  id=452 depth=8 X_2  thresh: 0  info  0.005593973126440832
# left:
# leaf: id=905 depth=9 value=0
# right:
# leaf: id=906 depth=9 value=0
# right:
#  id=226 depth=7 X_1  thresh: 0  info  0.002512769813807769
# left:
# leaf: id=453 depth=8 value=0
# right:
# leaf: id=454 depth=8 value=0
# right:
#  id=56 depth=5 X_1  thresh: 0  info  0.0037598619329388128
# left:
#  id=113 depth=6 X_2  thresh: 0  info  0.008407434346611342
# left:
#  id=227 depth=7 X_4  thresh: 0  info  0.0023657971738016426
# left:
# leaf: id=455 depth=8 value=0
# right:
#  id=456 depth=8 X_8  thresh: 0  info  0.003111111111111231
# left:
# leaf: id=913 depth=9 value=0
# right:
# leaf: id=914 depth=9 value=0
# right:
#  id=228 depth=7 X_4  thresh: 0  info  0.009191232048374992
# left:
# leaf: id=457 depth=8 value=0
# right:
# leaf: id=458 depth=8 value=0
# right:
# leaf: id=114 depth=6 value=0
# right:
#  id=28 depth=4 X_8  thresh: 0  info  0.0020236896095898183
# left:
#  id=57 depth=5 X_2  thresh: 0  info  0.001843734422625698
# left:
#  id=115 depth=6 X_7  thresh: 0  info  0.0027073068672544
# left:
#  id=231 depth=7 X_1  thresh: 0  info  0.0011574430476510855
# left:
#  id=463 depth=8 X_4  thresh: 0  info  0.0016817895373789082
# left:
# leaf: id=927 depth=9 value=0
# right:
# leaf: id=928 depth=9 value=0
# right:
# leaf: id=464 depth=8 value=0
# right:
# leaf: id=232 depth=7 value=0
# right:
#  id=116 depth=6 X_1  thresh: 0  info  0.003926797541446814
# left:
#  id=233 depth=7 X_7  thresh: 0  info  0.0026078242465749635
# left:
#  id=467 depth=8 X_4  thresh: 0  info  0.0024327391406609444
# left:
# leaf: id=935 depth=9 value=0
# right:
# leaf: id=936 depth=9 value=0
# right:
# leaf: id=468 depth=8 value=0
# right:
# leaf: id=234 depth=7 value=0
# right:
# leaf: id=58 depth=5 value=0
# right:
#  id=14 depth=3 X_3  thresh: 0  info  0.0005486450866867831
# left:
#  id=29 depth=4 X_4  thresh: 0  info  0.0004986905189068302
# left:
#  id=59 depth=5 X_1  thresh: 0  info  0.0044473033498309
# left:
#  id=119 depth=6 X_2  thresh: 0  info  0.0009620116718439542
# left:
#  id=239 depth=7 X_8  thresh: 0  info  0.00034380364383568285
# left:
#  id=479 depth=8 X_7  thresh: 0  info  0.00017614960796785706
# left:
# leaf: id=959 depth=9 value=0
# right:
# leaf: id=960 depth=9 value=0
# right:
# leaf: id=480 depth=8 value=0
# right:
#  id=240 depth=7 X_8  thresh: 0  info  0.0016830535861679374
# left:
#  id=481 depth=8 X_7  thresh: 0  info  0.0013767762360631375
# left:
# leaf: id=963 depth=9 value=0
# right:
# leaf: id=964 depth=9 value=0
# right:
# leaf: id=482 depth=8 value=0
# right:
#  id=120 depth=6 X_2  thresh: 0  info  0.012166639508989219
# left:
# leaf: id=241 depth=7 value=0
# right:
# leaf: id=242 depth=7 value=0
# right:
#  id=60 depth=5 X_7  thresh: 0  info  0.00042016040122105913
# left:
#  id=121 depth=6 X_2  thresh: 0  info  0.00023759362287295582
# left:
#  id=243 depth=7 X_1  thresh: 0  info  0.0011182603552885029
# left:
#  id=487 depth=8 X_8  thresh: 0  info  0.0007275549113684443
# left:
# leaf: id=975 depth=9 value=0
# right:
# leaf: id=976 depth=9 value=0
# right:
#  id=488 depth=8 X_8  thresh: 0  info  0.008945004785393618
# left:
# leaf: id=977 depth=9 value=0
# right:
# leaf: id=978 depth=9 value=0
# right:
#  id=244 depth=7 X_1  thresh: 0  info  0.001551217925519932
# left:
#  id=489 depth=8 X_8  thresh: 0  info  2.2291615789760133e-05
# left:
# leaf: id=979 depth=9 value=0
# right:
# leaf: id=980 depth=9 value=0
# right:
#  id=490 depth=8 X_8  thresh: 0  info  0.0023561507936506465
# left:
# leaf: id=981 depth=9 value=0
# right:
# leaf: id=982 depth=9 value=0
# right:
#  id=122 depth=6 X_1  thresh: 0  info  0.004202321074749105
# left:
#  id=245 depth=7 X_2  thresh: 0  info  0.003389677256804724
# left:
#  id=491 depth=8 X_8  thresh: 0  info  0.008696298498587773
# left:
# leaf: id=983 depth=9 value=0
# right:
# leaf: id=984 depth=9 value=0
# right:
#  id=492 depth=8 X_8  thresh: 0  info  0.0167968750000001
# left:
# leaf: id=985 depth=9 value=0
# right:
# leaf: id=986 depth=9 value=2
# right:
# leaf: id=246 depth=7 value=0
# right:
#  id=30 depth=4 X_8  thresh: 0  info  0.001298401375086522
# left:
#  id=61 depth=5 X_2  thresh: 0  info  0.002034910872707907
# left:
#  id=123 depth=6 X_1  thresh: 0  info  0.0012394658293788385
# left:
#  id=247 depth=7 X_4  thresh: 0  info  0.0005399561525356311
# left:
#  id=495 depth=8 X_7  thresh: 0  info  0.004353741496598701
# left:
# leaf: id=991 depth=9 value=0
# right:
# leaf: id=992 depth=9 value=0
# right:
#  id=496 depth=8 X_7  thresh: 0  info  0.0021602369084593454
# left:
# leaf: id=993 depth=9 value=0
# right:
# leaf: id=994 depth=9 value=0
# right:
#  id=248 depth=7 X_4  thresh: 0  info  0.003193995288856777
# left:
# leaf: id=497 depth=8 value=0
# right:
# leaf: id=498 depth=8 value=0
# right:
#  id=124 depth=6 X_4  thresh: 0  info  0.0004064729384770649
# left:
#  id=249 depth=7 X_1  thresh: 0  info  0.0014520383379907353
# left:
#  id=499 depth=8 X_7  thresh: 0  info  0.006887052341597644
# left:
# leaf: id=999 depth=9 value=0
# right:
# leaf: id=1000 depth=9 value=0
# right:
# leaf: id=500 depth=8 value=0
# right:
#  id=250 depth=7 X_1  thresh: 0  info  0.0012595155120397605
# left:
#  id=501 depth=8 X_7  thresh: 0  info  0.00277244145610428
# left:
# leaf: id=1003 depth=9 value=0
# right:
# leaf: id=1004 depth=9 value=0
# right:
# leaf: id=502 depth=8 value=0
# right:
#  id=62 depth=5 X_2  thresh: 0  info  0.016808794523726633
# left:
#  id=125 depth=6 X_4  thresh: 0  info  0.0015071126489810682
# left:
# leaf: id=251 depth=7 value=0
# right:
# leaf: id=252 depth=7 value=0
# right:
# leaf: id=126 depth=6 value=0

# %%
print([a.id for a in leaf])
l = [a.id for a in leaf]
print([a.id for a in inner])
# Out:
# [3, 39, 655, 656, 328, 164, 82, 20, 10, 23, 24, 12, 895, 896, 897, 898, 224, 903, 904, 905, 906, 453, 454, 455, 913, 914, 457, 458, 114, 927, 928, 464, 232, 935, 936, 468, 234, 58, 959, 960, 480, 963, 964, 482, 241, 242, 975, 976, 977, 978, 979, 980, 981, 982, 983, 984, 985, 986, 246, 991, 992, 993, 994, 497, 498, 999, 1000, 500, 1003, 1004, 502, 251, 252, 126]
# [0, 1, 4, 9, 19, 40, 81, 163, 327, 2, 5, 11, 6, 13, 27, 55, 111, 223, 447, 448, 112, 225, 451, 452, 226, 56, 113, 227, 456, 228, 28, 57, 115, 231, 463, 116, 233, 467, 14, 29, 59, 119, 239, 479, 240, 481, 120, 60, 121, 243, 487, 488, 244, 489, 490, 122, 245, 491, 492, 30, 61, 123, 247, 495, 496, 248, 124, 249, 499, 250, 501, 62, 125]

# %% [markdown]
# pruning

# %%
def pruneClass(classifier):
    import copy
    max_accuracy = score(Y_test, Y_pred, [2])
    for node in inner:
        print(node.id, end=", ")
        temp = copy.deepcopy(classifier)
        temp.pruning([node.id])
        temp_preds = list(temp.predict(X_test))
        accuracy = score(Y_test, temp_preds, [2])
        if accuracy > max_accuracy:
            best_one = temp
            max_accuracy = accuracy
            print(max_accuracy, node.id)
    return best_one

# %%
best_one = pruneClass(classifier)
newbest = pruneClass(best_one)
# Out:
# 0, 1, 4, 9, 19, 40, 81, 163, 327, 2, 5, 11, 6, 13, 27, 55, 111, 223, 447, 448, 112, 225, 451, 452, 226, 56, 113, 227, 456, 228, 28, 57, 115, 231, 463, 116, 233, 467, 14, 29, 59, 119, 239, 479, 240, 481, 120, 60, 121, 243, 487, 488, 244, 489, 490, 122, 245, 491, 492, 30, 61, 123, 247, 495, 496, 248, 124, 249, 499, 250, 501, 62, 125,
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 best_one = pruneClass(classifier)
#       2 newbest = pruneClass(best_one)
#
# Cell In[10], line 14, in pruneClass(classifier)
#      12         max_accuracy = accuracy
#      13         print(max_accuracy, node.id)
# ---> 14 return best_one
#
# UnboundLocalError: local variable 'best_one' referenced before assignment
